# %%
import pandas

# %%
def load_tf_names(path):
    """
    :param path: the path of the transcription factor list file.
    :return: a list of transcription factor names read from the file.
    """

    with open(path) as file:
        tfs_in_file = [line.strip() for line in file.readlines()]

    return

# %%
ex_matrix = pandas.read_csv("/data/passala/Collaborator_Data/Bruno_Ken_Collab/Mini_EX_Files/Full_clone/MINI-EX/INPUTS/forced_matrix.txt", sep='\t', header=0, index_col=0).T

# %%
ex_matrix
# Out:
# Maize_Cell1_AAACCTGAGAGCTTCT  0.000000  0.817443  0.000000  0.000000  \
# Maize_Cell1_AAACCTGAGTGATCGG       0.0  0.000000       0.0       0.0
# Maize_Cell1_AAACCTGCACTGTCGG       0.0  0.000000       0.0       0.0
# Maize_Cell1_AAACCTGGTGTGAAAT       0.0  0.769156       0.0       0.0
# Maize_Cell1_AAACCTGTCTCAAGTG       0.0  0.000000       0.0       0.0
# Maize_Cell1_AAACGGGAGGAGTTTA       0.0  0.000000       0.0       0.0
# ...                                ...       ...       ...       ...
# Set_Cells_3_TTTGGTTTCTGGGTCG       0.0  0.000000       0.0       0.0
# Set_Cells_3_TTTGTTGAGGCTCACC       0.0  0.000000       0.0       0.0
# Set_Cells_3_TTTGTTGCAACCAGAG       0.0  0.000000       0.0       0.0
# Set_Cells_3_TTTGTTGCAGTCTACA       0.0  0.000000       0.0       0.0
# Set_Cells_3_TTTGTTGGTGGTCTCG       0.0  0.000000       0.0       0.0
#
# Maize_Cell1_AAACCTGAGAGCTTCT  0.000000  0.000000  0.000000  0.000000  \
# ...

# %%
real_matrix = pandas.read_csv("/data/passala/Collaborator_Data/Bruno_Ken_Collab/Mini_EX_Files/Full_clone/MINI-EX/example/INPUTS/miniexExample_matrix.txt", sep='\t', header=0, index_col=0).T

# %%
real_matrix
# Out:
# geneid              AT1G67265  AT3G12100  AT4G03340  AT2G28360  AT3G13010  \
# CTACGTCTCGGATGGA-1          0          0          0          0          0
# TCGGGACGTCGAATCT-1          0          0          0          2          0
# CGGACTGGTGATGATA-2          0          0          0          0          0
# GTTCGGGTCACCATAG-2          0          1          0          0          0
# GACTAACTCGCTGATA-2          0          0          0          0          0
# ...                       ...        ...        ...        ...        ...
# GGCCGATCACAAGTAA-2          0          1          0          1          0
# CAGATCACATCGGAAG-1          0          0          0          0          0
# GTTCGGGGTGCCTGTG-3          0          0          0          0          0
# GGACATTGTGTTTGTG-3          0          1          1          0          0
# TAGACCATCGGTGTCG-2          0          0          0          0          0
#
# geneid              AT1G19080  AT3G04450  AT4G02070  AT1G74830  AT4G22470  \
# ...

# %%
tf_names = load_tf_names('/data/passala/Collaborator_Data/Bruno_Ken_Collab/Mini_EX_Files/Full_clone/MINI-EX/INPUTS/TF_list.txt')

# %%
tf_names
